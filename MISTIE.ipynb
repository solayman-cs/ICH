# %% [markdown]
# <a href="https://colab.research.google.com/github/solayman-cs/ICH/blob/main/MISTIE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt

# %%
# %cd /content/drive/My Drive/DataSets/processed/01
# Out:
# /content/drive/My Drive/DataSets/processed/01

# %%
os.listdir()
# Out:
# ['Manual_Mask_1_Reader_2.nii',
#  'Manual_Mask_1_Reader_1.nii',
#  'BRAIN_1_header.csv',
#  'Manual_Mask_1_Reader_2_header.csv',
#  'Manual_Mask_1_Reader_1_header.csv',
#  'BRAIN_1_Anonymized.nii',
#  'BRAIN_1_Anonymized_Mask.nii']

# %%
dem_path = '/content/drive/My Drive/DataSets/processed/Demographics.csv' 
df_dem = pd.read_csv(dem_path)
df_dem.shape
# Out:
# (35, 7)

# %%
df_dem.head()
# Out:
#    id  age     sex                       race             hispanic  \
# 0   1   50  Female     Black/African American  Not Hispanic/Latino
# 1   2   66  Female     Black/African American  Not Hispanic/Latino
# 2   3   43    Male     Black/African American  Not Hispanic/Latino
# 3   4   70    Male            White/Caucasian  Not Hispanic/Latino
# 4   5   78    Male  Asian or Pacific Islander  Not Hispanic/Latino
#
#              dx  site
# 0  ICH with IVH     2
# 1           ICH    15
# 2           ICH    10
# 3           ICH    14
# 4  ICH with IVH    16

# %% [markdown]
# - Anonymized where the face and the
# ears have been removed from the image
# - diagnosis (dx)
# - IVH is present initially in one quarter of patients with ICH or may occur as subsequent extension of the ICH component.
# - site ID (again maps back to the original data)

# %%
df_dem['sex'].value_counts()
# Out:
# Male      21
# Female    14
# Name: sex, dtype: int64

# %%
df_dem['dx'].value_counts()
# Out:
# ICH             20
# ICH with IVH    14
# Primary IVH      1
# Name: dx, dtype: int64

# %%
path = 'BRAIN_1_Anonymized.nii'
img = nib.load(path)
img_data = img.get_fdata()

# %%
indx = 8

# %%
plt.imshow(img_data[:,:,indx])
plt.title('CT Slice')
# Out:
# Text(0.5, 1.0, 'CT Slice')

# %%
mask_path_1 = 'Manual_Mask_1_Reader_1.nii'
mask1 = nib.load(mask_path_1)
img_mask1 = mask1.get_fdata()

# %%
plt.imshow(img_mask1[:,:,indx])
plt.title('Reader_1 Annotation')
# Out:
# Text(0.5, 1.0, 'Reader_1 Annotation')

# %%
mask_path_2 = 'Manual_Mask_1_Reader_2.nii'
mask2 = nib.load(mask_path_2)
img_mask2 = mask2.get_fdata()

# %%
plt.imshow(img_mask2[:,:,indx])
plt.title('Reader_1 Annotation')
# Out:
# Text(0.5, 1.0, 'Reader_1 Annotation')

# %%
fig = plt.figure()

plt.subplot(1, 2 , 1)
plt.imshow(img_mask1[:,:,indx])
plt.title('Reader_1 Annotation')

plt.subplot(1, 2, 2)
plt.imshow(img_mask2[:,:,indx])
plt.title('Reader_2 Annotation')


plt.show()

# %%
plt.imshow(img_data[:,:,4])
plt.title('CT Slice')
# Out:
# Text(0.5, 1.0, 'CT Slice')

# %%
fig = plt.figure()

plt.subplot(1, 2 , 1)
plt.imshow(img_mask1[:,:,4])
plt.title('Reader_1 Annotation')

plt.subplot(1, 2, 2)
plt.imshow(img_mask2[:,:,4])
plt.title('Reader_2 Annotation')


plt.show()
